# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Téléchargement des données

# %% [markdown]
# ## Données conso :

# %% [markdown]
# Les données sont téléchargées sur : <br/>
# https://www.rte-france.com/fr/eco2mix/eco2mix-telechargement

# %%
data = pd.read_excel("data.xlsx")
data.head()
# Out:
#       Mois              Qualité               Territoire  Production totale  \
# 0  0000-00  Données consolidées                Grand-Est               7296
# 1  0000-00  Données définitives       Nouvelle-Aquitaine               4523
# 2  0000-00  Données définitives     Auvergne-Rhône-Alpes               8890
# 3  0000-00  Données définitives  Bourgogne-Franche-Comté                152
# 4  0000-00  Données définitives                 Bretagne                197
#
#    Production nucléaire  Production thermique totale  \
# 0                5505.0                          864
# 1                3740.0                           26
# 2                5946.0                           32
# 3                   NaN                           19
# 4                   NaN                            3
#
#    Production thermique charbon  Production thermique fioul  \
# 0                         153.0                           8
# 1                           NaN                           9
# 2                           4.0                          17
# 3                           0.0                           0
# 4                           NaN                           3
#
#    Production thermique gaz  Production hydraulique  \
# 0                       701                     537
# 1                        16                     162
# 2                        10                    2632
# 3                        19                      19
# 4                         0                      46
#
#                      ...                     Production bio-énergies  \
# 0                    ...                                          70
# 1                    ...                                         131
# 2                    ...                                          79
# 3                    ...                                          20
# 4                    ...                                          37
#
#    Consommation totale  Solde exportateur  Echanges export  Echanges import  \
# 0                 3364             3876.0              NaN              NaN
# 1                 3222             1300.0              NaN              NaN
# 2                 5010             3658.0              NaN              NaN
# 3                 1533            -1383.0              NaN              NaN
# 4                 1493            -1300.0              NaN              NaN
#
#    Echanges avec le Royaume-uni  Echanges avec l'Espagne  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
#
#    Echanges avec l'Italie  Echanges aves la Suisse  \
# 0                     NaN                      NaN
# 1                     NaN                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4                     NaN                      NaN
#
#    Echanges avec l'Allemagne et la Belgique
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 22 columns]

# %%
#Afin de coller avec les données DJU nous allons concentrer l'étude sur une région, et nous ne gardons que 
#Les données définitives.
conso = data.loc[data['Territoire'] == 'Auvergne-Rhône-Alpes']
conso = conso.loc[conso['Qualité'] == 'Données définitives']

#Les colonnes qui nous intéressent désormais sont la date et la conso : 
conso = conso[['Mois', 'Consommation totale']]

#Pas de données avant Janvier 2014, on enlève donc les mois précédents : 
conso = conso.loc[conso['Mois'] > "2013-12"]

#Les données DJU vont jusqu'au 05/2018 :
conso = conso.loc[conso['Mois'] < "2018-05"]

#On renomme les colonnes : 
conso = conso.rename(columns={'Mois':'date', 'Consommation totale':'consommation'})

#Split la colonne date en Année et Mois : 
#conso['annee'], conso['mois'] = conso['date'].str.split(pat='-').str
#conso = conso.drop(columns='date')

#On convertie ensuite la date en datetime :
from datetime import datetime
conso['date'] = pd.to_datetime(conso['date'], format='%Y-%m')
#Set index sur date : 
conso = conso.set_index('date')

conso.head()
# Out:
#             consommation
# date
# 2014-01-01          6693
# 2014-02-01          6013
# 2014-03-01          5965
# 2014-04-01          5139
# 2014-05-01          4858

# %% [markdown]
# ## Données DJU

# %% [markdown]
# Données téléchargées sur : <br/>
# https://cegibat.grdf.fr/simulateur/calcul-dju

# %%
dju = pd.read_excel('DJU.xlsx')

#On doit maintenant mettre en forme le Df, afin d'avoir une colonne année, une mois, une valeur :
dju = dju.stack()
dju = pd.DataFrame(dju)
dju = dju.reset_index()
dju = dju.rename(columns={"level_0":'annee', 'level_1':'mois', 0:'valeur'})

# %% [markdown]
# Il nous faut maintenant un index contenant la date complète; <br/>
# On doit d'abord transformer le nom du mois en chiffre :

# %%
def moisEnNum(shortMonth):
    m = {
            'Janvier' : 1,
            'Février' : 2,
            'Mars' : 3,
            'Avril' : 4,
            'Mai' : 5,
            'Juin' : 6,
            'Juillet' : 7,
            'Août' : 8,
            'Septembre' : 9, 
            'Octobre' : 10,
            'Novembre' : 11,
            'Décembre' : 12
    }
    resultats = []
    for i in shortMonth:
        out = m[i]
        resultats.append(out)    
    return resultats
    

dju['mois_num'] = moisEnNum(dju['mois'])

#On transforme ensuite cette colonne en date, ainsi que la colonne année : 
dju['date'] = dju['mois_num'].map(str) + '/' +  dju['annee'].map(str)
dju['date'] = pd.to_datetime(dju['date'], format='%m/%Y')

#On enlève les valeurs après Mai 2018 : 
dju = dju.loc[dju.date < '2018/05/01']

#On set l'index sur date: 
dju = dju.set_index('date')

#On ne garde que la colonne valeur : 
dju = dju[['valeur']]
dju.head()
# Out:
#             valeur
# date
# 2014-01-01   333.3
# 2014-02-01   294.7
# 2014-03-01   278.5
# 2014-04-01   184.0
# 2014-05-01   121.4

# %% [markdown]
# ## Visualisation :

# %%
conso.plot(y='consommation', figsize=[14,4])
plt.xlabel('Année')
plt.ylabel('Consommation')
#plt.savefig("Graphiques/")
plt.show()

# %%
dju.plot(y='valeur', figsize=[14,4])
plt.xlabel('Année')
plt.ylabel('DJU')
#plt.savefig("Graphiques/")
plt.show()

# %% [markdown]
# # Mission 1 : Corrigez les données de consommation mensuelles de l'effet température (dues au chauffage électrique) en utilisant une régression linéaire.

# %%
all_data = pd.merge(conso, dju, left_index=True, right_index=True)

# %%
import statsmodels.formula.api as smf

reg_simp = smf.ols('consommation~valeur', data=all_data).fit()

# %%
print(reg_simp.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           consommation   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     526.5
# Date:                Sat, 13 Jul 2019   Prob (F-statistic):           3.34e-28
# Time:                        15:47:05   Log-Likelihood:                -364.83
# No. Observations:                  52   AIC:                             733.7
# Df Residuals:                      50   BIC:                             737.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4464.8367     63.700     70.092      0.000    4336.892    4592.781
# valeur         5.9567      0.260     22.946      0.000       5.435       6.478
# ==============================================================================
# Omnibus:                        0.645   Durbin-Watson:                   1.893
# Prob(Omnibus):                  0.724   Jarque-Bera (JB):                0.643
# Skew:                           0.248   Prob(JB):                        0.725
# Kurtosis:                       2.775   Cond. No.                         410.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import seaborn as sns

all_data['pred'] = reg_simp.predict()

conso.plot(y='consommation', figsize=[14,4])
all_data['pred'].plot(label='Données corrigées')
plt.legend()
plt.xlabel('Année')
plt.ylabel('Consommation')
#plt.savefig("Graphiques/")
plt.show()

# %% [markdown]
# # Mission 2 : Effectuez une désaisonnalisation à l'aide des moyennes mobiles

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
x = pd.DataFrame(all_data['pred'], index = all_data.index)
x.head()
# Out:
#                    pred
# date
# 2014-01-01  6450.207493
# 2014-02-01  6220.278563
# 2014-03-01  6123.779894
# 2014-04-01  5560.870987
# 2014-05-01  5187.981065

# %%
decomp_x = seasonal_decompose(x,  model='additive')
decomp_x.plot() #Plot en plus gros
plt.show()

# %% [markdown]
# Voir sur quel type de Moyenne mobile on est

# %%
z = decomp_x.trend
z = pd.DataFrame(z, index=x.index)

# %%
x['pred'].plot(figsize=(14,4), label='Conso')
z['pred'].plot(figsize=(14,4), label='Moyenne mobile')
plt.legend()
plt.xlabel('Année')
plt.ylabel('Consommation')
#plt.savefig("Graphiques/")
plt.show()

# %% [markdown]
# # Mission 3 : Effectuez une prévision de la consommation sur un an

# %% [markdown]
# On commence par prendre une échantillon de x : <br/>
# on effectuera la prédiction sur Mai 2017 à Mai 2018, on enlève donc ces valeurs :

# %%
y = x.loc[x.index <= '2017-05-01']
delta = x.loc[x.index > '2017-05-01']

# %% [markdown]
# ## Méthode de Holt Winters :

# %%
from statsmodels.tsa.api import ExponentialSmoothing

# %%
hw = ExponentialSmoothing(np.asarray(y['pred']), seasonal_periods=12, trend='add', seasonal='add').fit()
hw_pred = hw.forecast(12)

conf_1 = [elt*0.95 for elt in hw_pred]
conf_2 = [elt*1.05 for elt in hw_pred]

plt.figure(figsize=(14,6))
plt.plot(y['pred'], label='Consommation')
plt.plot(pd.date_range(y.index[len(y)-1], periods=12, freq='M'), hw_pred, label='Predit')
plt.plot(pd.date_range(y.index[len(y)-1], periods=12, freq='M'), conf_1, color='g', linestyle='--', 
         label = 'Interval de confiance')
plt.plot(pd.date_range(y.index[len(y)-1], periods=12, freq='M'), conf_2, color='g', linestyle='--')
plt.legend()
plt.xlabel('Année')
plt.ylabel('Consommation')
#plt.savefig("Graphiques/")
plt.show()

# %% [markdown]
# Pas sûr pour l'interval de confiance, vérifier avec Laura

# %% [markdown]
# Regardons maintenant si la courbe pred ressemble bien à celle que l'on a pour 2018 :

# %%
plt.figure(figsize=(14,6))
plt.plot(delta['pred'], label='Consommation')
plt.plot(pd.date_range(y.index[len(y)-1], periods=12, freq='M'), hw_pred, label='Predit')
plt.plot(pd.date_range(y.index[len(y)-1], periods=12, freq='M'), conf_1, color='g', linestyle='--',
        label = 'Interval de confiance')
plt.plot(pd.date_range(y.index[len(y)-1], periods=12, freq='M'), conf_2, color='g', linestyle='--')
plt.legend()
plt.xlabel('Année')
plt.ylabel('Consommation')
#plt.savefig("Graphiques/")
plt.show()

# %% [markdown]
# ## Méthode SARIMA :

# %% [markdown]
# ### Stationnarisation de la série :

# %%
from functions import plot_sortie_acf
from statsmodels.tsa.stattools import acf, pacf

# %%
z = z.dropna()

# %%
y_len = len(y['pred']) # variable nécessaire pour l'utilisation de plot_sortie_acf

plot_sortie_acf(acf(np.asarray(y['pred'])), y_len)

# %%
from pandas import Series
from statsmodels.tsa.stattools import adfuller
series = y['pred']
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -3.793415
# p-value: 0.002975
# Critical Values:
# 	1%: -3.661
# 	5%: -2.961
# 	10%: -2.619

# %% [markdown]
# Procédons tout d'abord à une différenciation :

# %%
y_dif1 = y['pred'] - y['pred'].shift(1)

plot_sortie_acf(acf(np.asarray(y_dif1[1:])), y_len)

# %%
from pandas import Series
from statsmodels.tsa.stattools import adfuller
series = y_dif1[1:]
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -4.859594
# p-value: 0.000042
# Critical Values:
# 	1%: -3.679
# 	5%: -2.968
# 	10%: -2.623

# %% [markdown]
# On observe une décroissance lente vers 0 ; ce qui traduit un problème de non-stationnarité. On effectue donc une différenciation (𝐼−𝐵)

# %%
y_dif_1_12 = y_dif1 - y_dif1.shift(12)

plot_sortie_acf(acf(np.asarray(y_dif_1_12[13:])), y_len)

# %% [markdown]
# Test de dickey fuller à faire pour vérifier

# %%
from pandas import Series
from statsmodels.tsa.stattools import adfuller
series = y_dif_1_12[13:]
X = series.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.431316
# p-value: 0.567174
# Critical Values:
# 	1%: -3.833
# 	5%: -3.031
# 	10%: -2.656

# %% [markdown]
# Le processus n'est pas stationnaire

# %% [markdown]
# ### Identification, estimation et validation de modèles

# %% [markdown]
# On s’appuie sur les autocorrélogrammes simple et partiels estimés :

# %%
plot_sortie_acf(acf(np.asarray(y['pred'])), y_len)

# %%
plot_sortie_acf(pacf(np.asarray(y['pred'])), y_len, pacf=True)

# %% [markdown]
# Wtf ?

# %% [markdown]
# L'autocorrélogramme partiel fait n'importe quoi là par contre

# %%
from statsmodels.tsa.statespace.sarimax import *
from statsmodels.stats.diagnostic import acorr_ljungbox

# %%
model1 = SARIMAX(np.asarray(y['pred']), order=(1,1,1), seasonal_order=(1,1,1,1))
results1 = model1.fit()
print(results1.summary())

print('Retard : p-value')
for elt in [6, 12, 18, 24, 30, 36]:
    print('{} : {}'.format(elt, acorr_ljungbox(results1.resid, lags=elt)[1].mean()))
# Out:
#                                  Statespace Model Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                   41
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 1)   Log Likelihood                -297.831
# Date:                           Sat, 13 Jul 2019   AIC                            605.661
# Time:                                   17:24:09   BIC                            613.979
# Sample:                                        0   HQIC                           608.645
#                                             - 41
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6348      0.076      8.400      0.000       0.487       0.783
# ma.L1         -0.9992      0.107     -9.322      0.000      -1.209      -0.789
# ar.S.L1        0.6348      0.076      8.400      0.000       0.487       0.783
# ma.S.L1       -0.9992      0.107     -9.322      0.000      -1.209      -0.789
# sigma2      2.028e+05    5.3e-07   3.82e+11      0.000    2.03e+05    2.03e+05
# ===================================================================================
# Ljung-Box (Q):                       65.40   Jarque-Bera (JB):                 2.40
# Prob(Q):                              0.00   Prob(JB):                         0.30
# Heteroskedasticity (H):               2.16   Skew:                            -0.29
# Prob(H) (two-sided):                  0.18   Kurtosis:                         4.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.66e+26. Standard errors may be unstable.
# Retard : p-value
# 6 : 0.20037818197160584
# 12 : 0.46134902491532775
# 18 : 0.6207209316262138
# 24 : 0.7137987881725527
# 30 : 0.7709095880375603
# 36 : 0.8086221318777358

# %%
pred_model3 = results1.get_forecast(12)
pred = pred_model3
pred_l = [np.exp(elt[0]) for elt in pred_model3.conf_int(alpha=0.05)]
pred_u = [np.exp(elt[1]) for elt in pred_model3.conf_int(alpha=0.05)]

plt.figure(figsize=(14,6))
plt.plot(y['pred'], label='pred')
plt.plot(pd.date_range(y.index[len(y)-1]), pred, color='r', label='Predit')
plt.plot(pd.date_range(y.index[len(y)-1]), pred_l, color='g', linestyle='--')
plt.plot(pd.date_range(y.index[len(y)-1]), pred_u, color='g', linestyle='--')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-d613674abe6e> in <module>
#       6 plt.figure(figsize=(14,6))
#       7 plt.plot(y['pred'], label='pred')
# ----> 8 plt.plot(pd.date_range(y.index[len(y)-1]), pred, color='r', label='Predit')
#       9 plt.plot(pd.date_range(y.index[len(y)-1]), pred_l, color='g', linestyle='--')
#      10 plt.plot(pd.date_range(y.index[len(y)-1]), pred_u, color='g', linestyle='--')
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in date_range(start, end, periods, freq, tz, normalize, name, closed, **kwargs)
#    2747     return DatetimeIndex(start=start, end=end, periods=periods,
#    2748                          freq=freq, tz=tz, normalize=normalize, name=name,
# -> 2749                          closed=closed, **kwargs)
#    2750
#    2751
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in __new__(cls, data, freq, start, end, periods, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name, verify_integrity)
#     379                 return cls._generate(start, end, periods, name, freq, tz=tz,
#     380                                      normalize=normalize, closed=closed,
# --> 381                                      ambiguous=ambiguous)
#     382
#     383         if not isinstance(data, (np.ndarray, Index, ABCSeries)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in _generate(cls, start, end, periods, name, freq, tz, normalize, ambiguous, closed)
#     468                   tz=None, normalize=False, ambiguous='raise', closed=None):
#     469         if com._count_not_none(start, end, periods, freq) != 3:
# --> 470             raise ValueError('Of the four parameters: start, end, periods, '
#     471                              'and freq, exactly three must be specified')
#     472
#
# ValueError: Of the four parameters: start, end, periods, and freq, exactly three must be specified

# %% [markdown]
# https://www.datasciencecentral.com/profiles/blogs/tutorial-forecasting-with-seasonal-arima

# %% [markdown]
# https://www.seanabu.com/2016/03/22/time-series-seasonal-ARIMA-model-in-python/

# %% [markdown]
# https://machinelearningmastery.com/time-series-data-stationary-python/

# %% [markdown]
# https://machinelearningmastery.com/time-series-data-stationary-python/

# %% [markdown]
# https://www.kaggle.com/sumi25/understand-arima-and-tune-p-d-q
